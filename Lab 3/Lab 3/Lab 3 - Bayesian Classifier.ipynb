# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math

# %matplotlib inline

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    ## HINT 2: Do you need to cast the data you read from the file?
    data = np.genfromtxt(file_name, delimiter=',')
    return data

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?

    test_data = np.genfromtxt('test_data.csv', delimiter=',')
    
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?

    test_data_true = np.genfromtxt('test_data_true.csv', delimiter=',')
    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

numClasses = 3 
M = training_data.shape[0]
N = training_data.shape[1] - 1
K = test_data.shape[0]

X = training_data[:, 1:]
X_Test = test_data
Y = training_data[:, 0]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']
for i in range(numClasses):
    class_data = X[Y == i + 1]
    plt.scatter(class_data[:, 0], class_data[:, 1], c=colors[i], label=f'Class {i+1}')
plt.legend()
plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:
    - The classes look naturally clustered and separate from each other, though with slight overlapping near boundaries.
    - Class 1 (red) is situated at the bottom. red points have low values on the Y-axis (feature 2). This means feature 2 has a low mean for Class 1 compared to the others.
    - Class 2 (green) is situated at the top. green points have high values on the Y-axis (feature 2). This means feature 2 has a high mean for Class 2 compared to the others.
    - Class 3 (blue) is situated mostly to the right side of plot. blue points have high values on the X-axis (feature 1). This means feature 1 has a high mean for Class 3 compared to the others.
    - Distributions appear roughly Gaussian.
'''
# Out:
# '\n    Your Answer:\n    - The classes look naturally clustered and separate from each other, though with slight overlapping near boundaries.\n    - Class 1 (red) is situated at the bottom. red points have low values on the Y-axis (feature 2). This means feature 2 has a low mean for Class 1 compared to the others.\n    - Class 2 (green) is situated at the top. green points have high values on the Y-axis (feature 2). This means feature 2 has a high mean for Class 2 compared to the others.\n    - Class 3 (blue) is situated mostly to the right side of plot. blue points have high values on the X-axis (feature 1). This means feature 1 has a high mean for Class 3 compared to the others.\n    - Distributions appear roughly Gaussian.\n'

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)
                             
for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.
    class_indices = (Y == classIndex + 1)
    class_data = X[class_indices]
    
    pClasses.append(round(class_data.shape[0] / M, 5))
    estimate_means.append(np.mean(class_data, axis=0))
    estimate_covariances.append(np.cov(class_data, rowvar=False))

estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.sum(pClasses)==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    N = X.shape[0]
    X_mu = X - mu
    sigma_inv = np.linalg.inv(sigma)
    sigma_det = np.linalg.det(sigma)
    
    coef = 1.0 / (((2 * np.pi) ** (N / 2)) * (sigma_det ** 0.5))
    exponent = -0.5 * np.dot(np.dot(X_mu.T, sigma_inv), X_mu)
    
    prob = coef * np.exp(exponent)
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    current_x = X_Test[i].reshape(-1, 1)
    for c in range(numClasses):
        mu_c = estimate_means[c].reshape(-1, 1)
        sigma_c = estimate_covariances[c]
        prior_c = pClasses[c]
        
        likelihood = multivariate_normal_gaussian(current_x, mu_c, sigma_c)
        if isinstance(likelihood, np.ndarray):
            likelihood = likelihood[0][0]
        classProbabilities[c] = likelihood * prior_c
    
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities) + 1)

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("==================================================================================")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [2.65665784e-12 2.14602228e-17 2.49127039e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [1.54056683e-02 1.59735634e-10 1.94605829e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [7.93457498e-20 1.36558313e-03 5.38714441e-11]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [1.95767574e-06 1.94248594e-08 5.69467016e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [6.24058624e-06 4.98429092e-08 4.72787476e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [4.48750255e-36 3.09289299e-04 1.66265014e-17]
# Predicted class is : 2
# ==================================================================================
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [2.21652003e-03 1.16513696e-07 8.33829076e-05]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [8.51737974e-05 1.94837069e-06 2.24456978e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [7.22905256e-20 5.21797756e-03 1.70141207e-10]
# Predicted class is : 2
# ==================================================================================
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [3.13512054e-25 1.40323225e-06 7.46132695e-14]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [2.85104824e-09 3.52760690e-12 1.15601556e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [7.99407143e-04 1.19355384e-06 4.43426300e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [7.41757966e-26 3.31843848e-03 3.77646710e-13]
# Predicted class is : 2
# ==================================================================================
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [1.08875924e-03 1.60725423e-20 2.07171678e-13]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [5.73706007e-04 1.06973582e-05 4.58270916e-04]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [4.93586663e-15 1.81085234e-17 2.37752792e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [1.95400473e-03 5.81000364e-12 1.27193892e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [2.59961932e-03 2.66270152e-15 4.98117032e-10]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [6.30154336e-09 6.99971045e-12 5.27532689e-03]
# Predicted class is : 3
# ==================================================================================
# For test point:
-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [1.69855985e-03 4.89638596e-10 4.53856247e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [2.89373185e-03 2.92803660e-22 2.03699638e-14]
# Predicted class is : 1
# ==================================================================================
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [6.88542581e-03 6.52634331e-09 6.39613227e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [2.43488805e-17 3.87485187e-22 2.42543145e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [5.90908506e-09 3.86409758e-10 7.24789894e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [8.33432116e-03 1.52644030e-08 1.71443190e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [1.73200468e-02 5.85714390e-12 2.18925756e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.39448958e-10 3.09079673e-06 1.16946115e-05]
# Predicted class is : 3
# ==================================================================================
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [9.30686402e-03 1.91573728e-14 1.24384613e-09]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [5.29366305e-11 1.53336515e-14 3.20142648e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [1.04012483e-04 7.28488940e-22 1.99047721e-14]
# Predicted class is : 1
# ==================================================================================
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [2.43227772e-04 3.53447358e-23 5.08976697e-15]
# Predicted class is : 1
# ==================================================================================
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [1.31151792e-03 1.73947659e-08 4.93435424e-05]
# Predicted class is : 1
# ==================================================================================
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [4.11738354e-08 1.05375413e-09 2.48194450e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.08714143e-12 1.19555463e-02 2.34514741e-07]
# Predicted class is : 2
# ==================================================================================
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [9.59805679e-03 1.47630435e-08 3.15310120e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [6.66217643e-27 5.80146792e-04 7.70459137e-14]
# Predicted class is : 2
# ==================================================================================
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [3.74125130e-06 1.39222442e-13 5.58976172e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.45102222e-25 4.14235992e-03 5.08441270e-13]
# Predicted class is : 2
# ==================================================================================
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [4.60307797e-13 7.31375608e-03 2.20072862e-07]
# Predicted class is : 2
# ==================================================================================
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.52995223e-28 6.66107346e-04 2.45387820e-14]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [8.23186329e-22 5.87573358e-03 2.26791065e-11]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [8.81979842e-12 3.09765512e-15 2.31676457e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [4.14286692e-11 2.76742135e-15 1.09511272e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [3.57528900e-10 1.63141226e-13 4.07557363e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [
-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [3.51935707e-06 8.15323655e-06 1.63549436e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [3.82773844e-22 4.26862325e-04 5.07662281e-12]
# Predicted class is : 2
# ==================================================================================
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.10399164e-13 8.77552326e-04 2.21522472e-07]
# Predicted class is : 2
# ==================================================================================
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [3.88525987e-07 2.23259153e-09 6.23700065e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [1.94241414e-33 8.08699724e-05 2.36865824e-16]
# Predicted class is : 2
# ==================================================================================
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [6.53269239e-12 4.73880262e-16 7.50443902e-05]
# Predicted class is : 3
# ==================================================================================
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [6.15609961e-04 1.39965127e-23 3.55296982e-15]
# Predicted class is : 1
# ==================================================================================
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [1.69750340e-02 1.28313986e-11 3.41454804e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [3.77191348e-05 3.74181975e-07 3.07098884e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [5.99085620e-11 1.26602139e-14 3.18616550e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [3.83776967e-03 1.82739746e-07 4.60604304e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [1.71034097e-06 1.83495687e-08 5.75553917e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [7.11993866e-16 3.86459545e-03 1.25292680e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [2.72877038e-06 2.48570335e-07 4.03482615e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [3.29785174e-03 2.11366210e-14 1.93916422e-09]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [1.78030870e-19 7.44880153e-06 1.07085314e-11]
# Predicted class is : 2
# ==================================================================================
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [1.46025013e-02 2.13706764e-14 9.88706072e-10]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [2.47269441e-14 2.22924707e-04 7.92807862e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [3.12736184e-06 5.16562136e-07 3.49278553e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [3.88438961e-05 8.16956356e-08 2.03949763e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [8.04236574e-03 3.29678232e-09 3.24850499e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.09443424e-08 7.83648467e-11 5.67100725e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [8.28528823e-13 2.52943544e-16 1.57148960e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [2.82202351e-15 9.38323958e-03 2.06152427e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [3.68855929e-03 2.76804641e-19 1.20295991e-12]
# Predicted class is : 1
# ==================================================================================
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.17514537e-08 4.16258587e-11 3.30254244e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.47743842e-36 1.26593594e-04 1.38471340e-17]
# Predicted class is : 2
# ==================================================================================
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [2.55797565e-03 8.59747932e-07 1.19501572e-05]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [2.80625664e-24 1.57902965e-03 1.44685681e-12]
# Predicted class is : 2
# ==================================================================================
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [3.74322741e-03 1.08371182e-12 2.87592447e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [1.74349201e-03 2.33168073e-15 4.97071387e-10]
# Predicted class is : 1
# ==================================================================================
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [1.54082086e-02 2.13032659e-11 3.64042361e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [4.72477124e-03 1.67499135e-15 7.84330065e-11]
# Predicted class is : 1
# ==================================================================================
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [6.66452799e-03 1.26879362e-18 2.06836199e-12]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.10232024e-24 6.65534338e-04 1.04925358e-12]
# Predicted class is : 2
# ==================================================================================
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [2.77341468e-06 6.36140285e-04 1.75333176e-04]
# Predicted class is : 2
# ==================================================================================
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [1.98382189e-15 1.25903670e-02 8.98397173e-09]
# Predicted class is : 2
# ==================================================================================
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.19044507e-19 5.98523998e-03 1.16796253e-10]
# Predicted class is : 2
# ==================================================================================
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [1.70946535e-04 6.35572218e-26 2.08119506e-16]
# Predicted class is : 1
# ==================================================================================
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [2.37661317e-08 2.14947163e-03 2.98255356e-05]
# Predicted class is : 2
# ==================================================================================
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [6.40173511e-03 6.49493309e-09 5.87198820e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [2.50110581e-03 6.09582620e-08 1.21408207e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [6.50251237e-16 1.24197042e-02 9.52152109e-09]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [1.80199662e-05 1.55729452e-08 1.41455309e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [1.94001366e-05 4.03152243e-05 1.16243175e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [2.64599287e-05 2.04910091e-08 1.25130659e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [4.08256860e-13 9.72122381e-03 6.86840489e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [1.35613731e-04 1.08954660e-13 1.55591797e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [9.09207374e-15 6.89966211e-20 6.28468561e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-7.52557256 -5.00051738]
# Class Probabilities:  [2.51157738e-03 3.92122427e-15 9.65812930e-11]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.31739532 -7.08917772]
# Class Probabilities:  [1.54195870e-02 5.00119038e-14 1.61625354e-09]
# Predicted class is : 1
# ==================================================================================
# For test point: [-2.87484239  6.36256125]
# Class Probabilities:  [7.72649155e-12 1.46455818e-03 6.08399488e-08]
# Predicted class is : 2
# ==================================================================================
# For test point:
-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [1.21776449e-02 9.10923308e-10 8.69874373e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.15411016e-10 1.61136857e-14 2.14731230e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [3.91562561e-08 4.12304600e-11 1.51409652e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.21737182e-25 4.47922253e-04 3.44259290e-13]
# Predicted class is : 2
# ==================================================================================
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [1.88563970e-15 1.45486444e-02 1.27910941e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.08814971e-13 3.43150764e-19 5.70639942e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [3.24347872e-15 1.43270946e-02 1.67075046e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.21986162e-05 1.82077317e-04 1.53200516e-05]
# Predicted class is : 2
# ==================================================================================
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [5.92313218e-10 1.68158736e-05 2.16241839e-05]
# Predicted class is : 3
# ==================================================================================
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.36139462e-25 4.62368596e-03 5.15492698e-13]
# Predicted class is : 2
# ==================================================================================
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [3.42106796e-04 2.57852000e-20 1.40732534e-13]
# Predicted class is : 1
# ==================================================================================
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [7.50740725e-37 1.40804265e-04 3.93901567e-18]
# Predicted class is : 2
# ==================================================================================
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [1.82845697e-11 9.37795637e-03 4.27115254e-07]
# Predicted class is : 2
# ==================================================================================
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [7.26906679e-31 1.26494691e-03 2.96688898e-15]
# Predicted class is : 2
# ==================================================================================
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [1.33741374e-02 6.75979647e-10 3.36837027e-07]
# Predicted class is : 1
# ==================================================================================
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.42365667e-08 2.72512451e-11 5.11207385e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [3.61194383e-04 3.02780126e-13 4.61772780e-10]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [1.48841267e-02 3.07365925e-12 1.02867041e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [3.81578840e-13 7.05255182e-16 6.09097804e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [4.71389743e-30 1.35766965e-03 6.67702789e-15]
# Predicted class is : 2
# ==================================================================================
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [1.74824711e-02 1.04643020e-12 7.63341742e-09]
# Predicted class is : 1
# ==================================================================================
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [6.02791474e-10 1.64832500e-12 5.77002407e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [6.53666704e-04 3.01026894e-07 4.02416431e-04]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [4.24089392e-03 2.40803091e-17 1.99132173e-11]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [3.90067950e-14 1.99337058e-06 3.91987419e-10]
# Predicted class is : 2
# ==================================================================================
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.24022521e-20 1.23588192e-04 1.14998953e-11]
# Predicted class is : 2
# ==================================================================================
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [8.36879260e-06 1.08784226e-08 2.07376912e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.27779554e-06 4.01674170e-09 4.78751104e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [5.70646940e-03 3.55398284e-12 5.35914561e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [2.41398826e-04 2.40821346e-09 4.40987226e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [5.01194382e-03 6.79109847e-10 2.04409868e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [1.74049392e-13 1.32352677e-19 4.77386996e-05]
# Predicted class is : 3
# ==================================================================================
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [1.32065187e-02 5.49532560e-12 1.26483842e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [5.65180680e-03 9.13836782e-21 1.46620302e-13]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [1.56838077e-03 1.68622479e-06 2.18047676e-04]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [3.34585023e-09 3.08897683e-12 5.04988200e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [1.98924074e-05 1.27562120e-07 3.48764979e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [4.76396613e-09 4.75506655e-12 5.27382771e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.05687295e-06 6.69089143e-06 5.86533153e-07]
# Predicted class is : 2
# ==================================================================================
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [2.33188458e-05 8.15055566e-14 2.01537704e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [1.11092805e-02 2.94812387e-15 1.61472650e-10]
# Predicted class is : 1
# ==================================================================================
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.43330819e-15 1.33327528e-02 1.28649090e-08]
# Predicted class is : 2
# ==================================================================================
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [6.54183179e-03 3.12325349e-10 8.01632084e-08]
# Predicted class is : 1
# ==================================================================================
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [6.21384089e-03 3.43118794e-20 3.23525043e-13]
# Predicted class is : 1
# ==================================================================================
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [8.95079399e-09 1.27730434e-11 5.11345347e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [3.55274764e-10 1.32007368e-13 3.97355046e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [4.45030454e-04 1.87474526e-07 4.62614285e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [4.92571947e-06 2.33293624e-05 1.23767751e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [6.48173001e-03 7.12290677e-10 1.68873371e-06]
# Predicted class is : 1
# ==================================================================================
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [1.44905363e-02 2.11651477e-12 7.96121575e-09]
# Predicted class is : 1
# ==================================================================================
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [1.01784503e-03 2.94584197e-08 8.44369255e-05]
# Predicted class is : 1
# ==================================================================================
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [7.86491828e-11 1.59106837e-13 1.39961935e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [2.03243083e-03 1.01083365e-08 2.43493082e-05]
# Predicted class is : 1
# ==================================================================================
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [7.95670153e-11 9.43760148e-15 2.23670696e-03]
# Predicted class is : 3
# ==================================================================================
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [1.67573463e-13 6.14114540e-19 6.03754012e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [5.15739742e-15 1.33333850e-22 1.68604344e-05]
# Predicted class is : 3
# ==================================================================================
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [4.67542438e-12 5.33505370e-11 3.31314265e-06]
# Predicted class is : 3
# ==================================================================================
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.43514776e-21 6.75189057e-03 2.25680345e-11]
# Predicted class is : 2
# ==================================================================================
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [1.03681722e-04 6.78560247e-05 5.54508411e-04]
# Predicted class is : 3
# ==================================================================================
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [3.55269410e-14 5.85006114e-18 9.69448945e-04]
# Predicted class is : 3
# ==================================================================================

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
accuracy = np.mean(np.array(predicted_classes) == test_data_true)
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.

x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)

for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        pt = np.array([X[i, j], Y[i, j]]).reshape(2, 1)
        prob = 0
        for c in range(numClasses):
            mu_c = estimate_means[c].reshape(2, 1)
            sigma_c = estimate_covariances[c]
            prior_c = pClasses[c]
            likelihood = multivariate_normal_gaussian(pt, mu_c, sigma_c)
            if isinstance(likelihood, np.ndarray):
                likelihood = likelihood[0][0]
            prob += likelihood * prior_c
        Z[i, j] = prob

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    The peaks of the 3D plot should roughly match the means of each of the 3 classes calculated earlier, and the spread of each peak should match their respective covariances. Also, it should align with the intuition gathered from the scatter plot in 2D.
'''
# Out:
# '\n    Your Answer:\n    The peaks of the 3D plot should roughly match the means of each of the 3 classes calculated earlier, and the spread of each peak should match their respective covariances. Also, it should align with the intuition gathered from the scatter plot in 2D.\n'
